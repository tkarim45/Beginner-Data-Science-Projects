# %%
# !pip install fastcore
# !pip install fastai
# Out:
# Requirement already satisfied: fastcore in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (1.5.29)
# Requirement already satisfied: pip in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastcore) (23.2.1)
# Requirement already satisfied: packaging in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastcore) (23.2)
# Requirement already satisfied: fastai in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (2.7.12)
# Requirement already satisfied: pip in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (23.2.1)
# Requirement already satisfied: packaging in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (23.2)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (1.5.29)
# Requirement already satisfied: torchvision>=0.8.2 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (0.15.2)
# Requirement already satisfied: matplotlib in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (3.7.3)
# Requirement already satisfied: pandas in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (2.0.3)
# Requirement already satisfied: requests in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (2.31.0)
# Requirement already satisfied: pyyaml in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>6.0.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (10.0.1)
# Requirement already satisfied: scikit-learn in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (1.3.1)
# Requirement already satisfied: scipy in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (1.10.1)
# Requirement already satisfied: spacy<4 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (3.7.1)
# Requirement already satisfied: torch<2.1,>=1.7 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from fastai) (2.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from spacy<4->fastai) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from spacy<4->fastai) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users
12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->fastai) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->fastai) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->fastai) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->fastai) (6.1.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pandas->fastai) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pandas->fastai) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from scikit-learn->fastai) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from scikit-learn->fastai) (3.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->fastai) (3.17.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.5.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (2.10.1)
# Collecting typing-extensions (from torch<2.1,>=1.7->fastai)
#   Obtaining dependency information for typing-extensions from https://files.pythonhosted.org/packages/24/21/7d397a4b7934ff4028987914ac1044d3b7d52712f30e2ac7a2ae5bc86dd0/typing_extensions-4.8.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: six>=1.5 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.16.0,>=0.7.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai) (0.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from jinja2->spacy<4->fastai) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from sympy->torch<2.1,>=1.7->fastai) (1.3.0)
# Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-macos 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.8.0 which is incompatible.
# tensorflow-probability 0.21.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed typing-extensions-4.8.0

# %%
from fastcore.all import *
import time
from fastai.vision.all import *
import pandas as pd
import numpy as np
import os

# %%
searches = 'Glaucoma', 'Cataracts', 'Uveitis', 'Crossed_Eyes', 'Bulging eyes'

# change the path
path = '/Users/taimourabdulkarim/Desktop/Fiverr/Reachsumim/Augmented Dataset'
data_dir_list = os.listdir(path)
print(data_dir_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/taimourabdulkarim/Documents/Github/Data-Science/Projects/Eye Disease Detection/2.ipynb Cell 3 line 5
#       <a href='vscode-notebook-cell:/Users/taimourabdulkarim/Documents/Github/Data-Science/Projects/Eye%20Disease%20Detection/2.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> # change the path
#       <a href='vscode-notebook-cell:/Users/taimourabdulkarim/Documents/Github/Data-Science/Projects/Eye%20Disease%20Detection/2.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> path = '/Users/taimourabdulkarim/Desktop/Fiverr/Reachsumim/Augmented Dataset'
# ----> <a href='vscode-notebook-cell:/Users/taimourabdulkarim/Documents/Github/Data-Science/Projects/Eye%20Disease%20Detection/2.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> data_dir_list = os.listdir(path)
#       <a href='vscode-notebook-cell:/Users/taimourabdulkarim/Documents/Github/Data-Science/Projects/Eye%20Disease%20Detection/2.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> print(data_dir_list)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/taimourabdulkarim/Desktop/Fiverr/Reachsumim/Augmented Dataset'

# %%
# remove the .DS_Store from the list
data_dir_list.remove('.DS_Store')
print(data_dir_list)
# Out:
# ['Glaucoma', 'Cataracts', 'Uveitis', 'Crossed_Eyes', 'Bulging eyes']

# %%
get_items = get_image_files(path)

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path)

dls.show_batch(max_n=10)

# %%
dls.vocab
# Out:
# ['Bulging eyes', 'Cataracts', 'Crossed_Eyes', 'Glaucoma', 'Uveitis']

# %%
blocks = (ImageBlock, CategoryBlock),
get_items = get_image_files,
splitter = RandomSplitter(valid_pct=0.2, seed=42),
dls.show_batch()

# %%
learn = vision_learner(dls, resnet34, metrics=accuracy)
learn.fine_tune(50)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.119964</td>
#       <td>0.792623</td>
#       <td>0.748299</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.813247</td>
#       <td>0.470187</td>
#       <td>0.823129</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.601783</td>
#       <td>0.357975</td>
#       <td>0.870748</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.457804</td>
#       <td>0.322073</td>
#       <td>0.877551</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.353055</td>
#       <td>0.324489</td>
#       <td>0.904762</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.275003</td>
#       <td>0.325995</td>
#       <td>0.904762</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.213081</td>
#       <td>0.318624</td>
#       <td>0.904762</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.169781</td>
#       <td>0.303660</td>
#       <td>0.911565</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.137413</td>
#       <td>0.291853</td>
#       <td>0.911565</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.111513</td>
#       <td>0.278552</td>
#       <td>0.918367</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.092237</td>
#       <td>0.334406</td>
#       <td>0.911565</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.076149</td>
#       <td>0.340530</td>
#       <td>0.918367</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.063011</td>
#       <td>0.292875</td>
#       <td>0.904762</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.052825</td>
#       <td>0.334445</td>
#       <td>0.897959</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.044132</td>
#       <td>0.306941</td>
#       <td>0.918367</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.036786</td>
#       <td>0.288944</td>
#       <td>0.918367</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# Conv2d                                    8192       True
# BatchNorm2d                               256        True
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# ReLU
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# ReLU
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# ReLU
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      64 x 256 x 12 x 12
# Conv2d                                    294912     True
# BatchNorm2d                               512        True
# ReLU
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# Conv2d                                    32768      True
# BatchNorm2d                               512        True
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ReLU
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ReLU
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ReLU
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ReLU
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ReLU
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 512 x 6 x 6
# Conv2d                                    1179648    True
# BatchNorm2d                               1024       True
# ReLU
# Conv2d                                    2359296    True
# BatchNorm2d                               1024       True
# Conv2d                                    131072     True
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    True
# BatchNorm2d                               1024       True
# ReLU
# Conv2d                                    2359296    True
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    True
# BatchNorm2d                               1024       True
# ReLU
# Conv2d                                    2359296    True
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      64 x 512 x 1 x 1
# AdaptiveAvgPool2d
# AdaptiveMaxPool2d
# ____________________________________________________________________________
#                      64 x 1024
# Flatten
# BatchNorm1d                               2048       True
# Dropout
# ____________________________________________________________________________
#                      64 x 512
# Linear                                    524288     True
# ReLU
# BatchNorm1d                               1024       True
# Dropout
# ____________________________________________________________________________
#                      64 x 5
# Linear                                    2560       True
# ____________________________________________________________________________
#
# Total params: 21,814,592
# Total trainable params: 21,814,592
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x146b99160>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Model unfrozen
#
# Callbacks:
#   - TrainEvalCallback
#   - CastToTensor
#   - Recorder
#   - ProgressCallback

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0002290867705596611)

# %%
import matplotlib.pyplot as plt

# Set font size for the entire plot
plt.rcParams['font.size'] = 7

interp = ClassificationInterpretation.from_learner(learn)
interp.plot_top_losses(20)
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00&lt;?]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
